# %%
import pandas

# %%
import csv

temp = r'E:/Moscow City Hack/datasets/phyton-master/rest_data.csv'

with open(temp, encoding="cp1251", errors='ignore') as f:
    cr = csv.reader(f, delimiter=',')
    # next(cr) gets the header row (row[0])
    i = next(cr).index('object_type')
    # list comprehension through remaining cr iterables
    filtered = [row for row in cr if row[i] == "кафе"]

# %%
with open('E:/Moscow City Hack/datasets/phyton-master/rest_data.csv', encoding="UTF8") as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
# Out:
# ['id', 'object_name', 'chain', 'object_type', 'address', 'number']
# ['151635', 'СМЕТАНА', 'нет', 'кафе', 'город Москва, улица Егора Абакумова, дом 9', '48']
# ['77874', 'Родник', 'нет', 'кафе', 'город Москва, улица Талалихина, дом 2/1, корпус 1', '35']
# ['24309', 'Кафе «Академия»', 'нет', 'кафе', 'город Москва, Абельмановская улица, дом 6', '95']
# ['21894', 'ПИЦЦЕТОРИЯ', 'да', 'кафе', 'город Москва, Абрамцевская улица, дом 1', '40']
# ['119365', 'Кафе «Вишневая метель»', 'нет', 'кафе', 'город Москва, Абрамцевская улица, дом 9, корпус 1', '50']
# ['27429', 'СТОЛ. ПРИ ГОУ СОШ № 1051', 'нет', 'столовая', 'город Москва, Абрамцевская улица, дом 15, корпус 1', '240']
# ['148815', 'Брусника', 'да', 'кафе', 'город Москва, переулок Сивцев Вражек, дом 6/2', '10']
# ['20957', 'Буфет МТУСИ', 'нет', 'столовая', 'город Москва, Авиамоторная улица, дом 8, строение 1', '90']
# ['20958', 'КПФ СЕМЬЯ-1', 'нет', 'столовая', 'город Москва, Авиамоторная улица, дом 8, строение 1', '150']
# ...

# %%
import csv
with open('E:/Moscow City Hack/datasets/phyton-master/rest_data.csv', encoding="UTF8") as f_in:
    with open('cafe.csv', 'w', newline='') as f_outfile:
        f_out = csv.writer(f_outfile, escapechar=' ',quoting=csv.QUOTE_NONE)

        for line in f_in:
            line = line.strip()
            row = []
            if 'кафе' in line:
                row.append(line)
                f_out.writerow(row)

# %%
 with open('cafe.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
# Out:
# ['151635 ', 'СМЕТАНА ', 'нет ', 'кафе ', ' "город  Москва ', '  улица  Егора  Абакумова ', '  дом  9 " ', '48']
# ['77874 ', 'Родник ', 'нет ', 'кафе ', ' "город  Москва ', '  улица  Талалихина ', '  дом  2/1 ', '  корпус  1 " ', '35']
# ['24309 ', 'Кафе  «Академия» ', 'нет ', 'кафе ', ' "город  Москва ', '  Абельмановская  улица ', '  дом  6 " ', '95']
# ['21894 ', 'ПИЦЦЕТОРИЯ ', 'да ', 'кафе ', ' "город  Москва ', '  Абрамцевская  улица ', '  дом  1 " ', '40']
# ['119365 ', 'Кафе  «Вишневая  метель» ', 'нет ', 'кафе ', ' "город  Москва ', '  Абрамцевская  улица ', '  дом  9 ', '  корпус  1 " ', '50']
# ['148815 ', 'Брусника ', 'да ', 'кафе ', ' "город  Москва ', '  переулок  Сивцев  Вражек ', '  дом  6/2 " ', '10']
# ['23394 ', 'Гогиели ', 'нет ', 'кафе ', ' "город  Москва ', '  Авиамоторная  улица ', '  дом  49/1 " ', '24']
# ['22579 ', 'Алло  Пицца ', 'да ', 'кафе ', ' "город  Москва ', '  улица  Авиаторов ', '  дом  14 " ', '32']
# ...

# %%
import csv
with open('E:/Moscow City Hack/datasets/phyton-master/rest_data.csv', encoding="UTF8") as f_in:
    with open('bar.csv', 'w', newline='') as f_outfile:
        f_out = csv.writer(f_outfile, escapechar=' ',quoting=csv.QUOTE_NONE)

        for line in f_in:
            line = line.strip()
            row = []
            if 'бар' in line:
                row.append(line)
                f_out.writerow(row)

# %%
with open('bar.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
# Out:
# ['139766 ', 'Паб  «ШемроК» ', 'нет ', 'бар ', ' "город  Москва ', '  Балаклавский  проспект ', '  дом  54 " ', '30']
# ['59265 ', 'Кафе-бар  Альбом ', 'нет ', 'кафе ', ' "город  Москва ', '  Новая  Басманная  улица ', '  дом  12 ', '  строение  2 " ', '80']
# ['20344 ', 'Кафе  Бар  Бульвар ', 'нет ', 'бар ', ' "город  Москва ', '  Бескудниковский  бульвар ', '  дом  40 ', '  корпус  3 " ', '60']
# ['28501 ', 'Авлабар ', 'нет ', 'ресторан ', ' "город  Москва ', '  Велозаводская  улица ', '  дом  6 " ', '40']
# ['19761 ', 'Бар  «Фитнес-бар» ', 'нет ', 'бар ', ' "город  Москва ', '  проспект  Вернадского ', '  дом  103 ', '  корпус  1 " ', '24']
# ['20632 ', 'БАР  В  ФИТНЕС  КЛУБЕ ', 'нет ', 'бар ', ' "город  Москва ', '  Глазовский  переулок ', '  дом  5 " ', '4']
# ['23185 ', 'Кафе-бар  «Караоке  MyzOn» ', 'нет ', 'кафе ', ' "город  Москва ', '  Вешняковская  улица ', '  дом  2 " ', '32']
# ...
